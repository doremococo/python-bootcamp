# %% [markdown]
# <a href="https://colab.research.google.com/github/doremococo/python-bootcamp/blob/main/day2_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#特定のタプルから、2番目の要素を取得する
taple = (1, 2, 3, 4, 5)
print(taple[1])

# tuple の内包表記
taple_02 = tuple(i for i in range(1, 11) if i == 2)

# ()で囲うとgenerateになるらしい
# taple_02 = (i for i in range(1, 11) if i == 2)
print(taple_02[0])
# Out:
# 2
# 2
