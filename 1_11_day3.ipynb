# %% [markdown]
# <a href="https://colab.research.google.com/github/doremococo/python-bootcamp/blob/main/1_11_day3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
my_dict = {"name": "Alice", "age": 30, "city": "New York"}
print(my_dict)
print("age：", my_dict["age"])
# Out:
# {'name': 'Alice', 'age': 30, 'city': 'New York'}
# age： 30
