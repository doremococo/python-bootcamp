# %% [markdown]
# <a href="https://colab.research.google.com/github/doremococo/dotfiles/blob/main/day1_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# append は使わずに、リスト内表記だけで実装
# リスト内表記 連続して計算した結果を表示
# sample = [i**2 for i in range(5)]
# [0, 1, 4, 9, 16]

#リスト内表記　条件式を含む
# sample = [i for i in range(5) if i % 2 == 0]
# [0, 2, 4]
threes_list = [i for i in range(1, 31) if i % 3 == 0]
print(threes_list)
# Out:
# [3, 6, 9, 12, 15, 18, 21, 24, 27, 30]
