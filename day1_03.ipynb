# %% [markdown]
# <a href="https://colab.research.google.com/github/doremococo/dotfiles/blob/main/day1_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
numList = []
for i in range(1, 31):
  if i % 3 == 0:
    numList.append(i)

print(numList)
# Out:
# [3, 6, 9, 12, 15, 18, 21, 24, 27, 30]
