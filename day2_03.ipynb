# %% [markdown]
# <a href="https://colab.research.google.com/github/doremococo/python-bootcamp/blob/main/day2_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# list を昇順にソートする
ls = [50, 20, 30, 40, 10, 200, 109, 456, 298]
temp = 0

# バブルソート
for i in range(0, len(ls)):
  if i == 4:
    break
  else:
    for j in range(len(ls) - 1, i, -1):
      if j == 0 :
        break
      else:
        print(i, j)
        if ls[j] < ls[j - 1]:
          ls[j], ls[j - 1] = ls[j - 1], ls[j]
          # temp = ls [j - 1]
          # ls[j - 1] = ls[j]
          # ls[j] = temp
print(ls)

# for i in range(0, 5):
#   for j in range(5, i, -1):
#     print(i, j)
# Out:
# 0 8
# 0 7
# 0 6
# 0 5
# 0 4
# 0 3
# 0 2
# 0 1
# 1 8
# 1 7
# 1 6
# 1 5
# 1 4
# 1 3
# 1 2
# 2 8
# 2 7
# 2 6
# 2 5
# 2 4
# 2 3
# 3 8
# 3 7
# 3 6
# 3 5
# 3 4
# [10, 20, 30, 40, 50, 109, 200, 298, 456]
