# %% [markdown]
# <a href="https://colab.research.google.com/github/doremococo/python-bootcamp/blob/main/1_15_day3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# lambdaを使い、第2要素でソートする
my_tupple = [(1,2),(2,3),(4,5)]
result = sorted(my_tupple, key= lambda x: -x[1])
print(f"第二要素に基づいて降順にソート: {result}")
# Out:
# 第二要素に基づいて降順にソート: [(4, 5), (2, 3), (1, 2)]
