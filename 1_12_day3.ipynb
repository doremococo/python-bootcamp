# %% [markdown]
# <a href="https://colab.research.google.com/github/doremococo/python-bootcamp/blob/main/1_12_day3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
d1 = {"A": 111, "B": 222, "C": 333}
d2 = {"D": 444, "E": 555}
d3 = {"F": 666}

# + ではダメだった
# print(d1 + d2 + d3)

# update を試してみる
d1.update(d2)
d1.update(d3)
print(d1)


# アンパックもいけるらしい
d1 = {"A": 111, "B": 222, "C": 333}

d_mix = {**d1, **d2, **d3}
print(d_mix)
# Out:
# {'A': 111, 'B': 222, 'C': 333, 'D': 444, 'E': 555, 'F': 666}
# {'A': 111, 'B': 222, 'C': 333, 'D': 444, 'E': 555, 'F': 666}
