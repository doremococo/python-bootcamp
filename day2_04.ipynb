# %% [markdown]
# <a href="https://colab.research.google.com/github/doremococo/python-bootcamp/blob/main/day2_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#listの2番目から4番目までを抽出

ls = [i for i in range(1, 6)]
# 2番目から3番目の数字
print(ls)
print("2番目：", ls[1], " 3番目：", ls[2], " 4番目：", ls[3])
# スライサーで実装
print(ls[1:4])
# Out:
# [1, 2, 3, 4, 5]
# 2番目： 2  3番目： 3  4番目： 4
# [2, 3, 4]
